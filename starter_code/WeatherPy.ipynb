# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 587

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # reate endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ebon
# Processing Record 2 of Set 1 | phulbani
# Processing Record 3 of Set 1 | humberto de campos
# Processing Record 4 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | mount gambier
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | trairi
# Processing Record 10 of Set 1 | edinburgh of the seven seas
# Processing Record 11 of Set 1 | nova vicosa
# Processing Record 12 of Set 1 | ilulissat
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | tanjungtiram
# Processing Record 15 of Set 1 | fortaleza
# Processing Record 16 of Set 1 | smithers
# Processing Record 17 of Set 1 | barra de santo antonio
# Processing Record 18 of Set 1 | afaahiti
# Processing Record 19 of Set 1 | rio grande
# Processing Record 20 of Set 1 | sortavala
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | murun-kuren
# Processing Record 23 of Set 1 | bilibino
# Processing Record 24 of Set 1 | utrik
# Processing Record 25 of Set 1 | tandalti
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | grytviken
# Processing Record 28 of Set 1 | ta`u
# Processing Record 29 of Set 1 | parambu
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | toyooka
# Processing Record 34 of Set 1 | coromandel
# Processing Record 35 of Set 1 | la ronge
# Processing Record 36 of Set 1 | kolonia
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | samana
# Processing Record 39 of Set 1 | deqen
# Processing Record 40 of Set 1 | wailua homesteads
# Processing Record 41 of Set 1 | uturoa
# Processing Record 42 of Set 1 | iraucuba
# Processing Record 43 of Set 1 | takoradi
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | kulia village
# City not found. Skipping...
# Processing Record 46 of Set 1 | puerto baquerizo moreno
# Processing Record 47 of Set 1 | cockburn town
# Processing Record 48 of Set 1 | san andres
# Processing Record 49 of Set 1 | praia da vitoria
# Processing Record 50 of Set 1 | badger
# Processing Record 0 of Set 2 | stanley
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | quellon
# Processing Record 5 of Set 2 | tefe
# Processing Record 6 of Set 2 | pyetrykaw
# Processing Record 7 of Set 2 | alpine
# Processing Record 8 of Set 2 | iqaluit
# Processing Record 9 of Set 2 | colonia
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | soledad de doblado
# Processing Record 12 of Set 2 | metu
# Processing Record 13 of Set 2 | margaret river
# Processing Record 14 of Set 2 | atafu village
# Processing Record 15 of Set 2 | kegeyli shahar
# Processing Record 16 of Set 2 | tobi village
# City not found. Skipping...
# Processing Record 17 of Set 2 | lido di ostia
# Processing Record 18 of Set 2 | ankang
# Processing Record 19 of Set 2 | ilebo
# Processing Record 20 of Set 2 | langsa
# Processing Record 21 of Set 2 | shiprock
# Processing Record 22 of Set 2 | waitangi
# Processing Record 23 of Set 2 | isafjordur
# Processing Record 24 of Set 2 | weno
# Processing Record 25 of Set 2 | ust'-kulom
# Processing Record 26 of Set 2 | roswell
# Processing Record 27 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 28 of Set 2 | lihue
# Processing Record 29 of Set 2 | launceston
# Processing Record 30 of Set 2 | guerrero negro
# Processing Record 31 of Set 2 | happy valley-goose bay
# Processing Record 32 of Set 2 | touros
# Processing Record 33 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 34 of Set 2 | puerto natales
# Processing Record 35 of Set 2 | zaysan
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | ambalangoda
# Processing Record 39 of Set 2 | newman
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | porto novo
# Processing Record 42 of Set 2 | nantucket
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | sandnessjoen
# Processing Record 45 of Set 2 | mabaruma
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | howard springs
# Processing Record 48 of Set 2 | qaqortoq
# Processing Record 49 of Set 2 | rivne
# Processing Record 0 of Set 3 | zakamensk
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | nguigmi
# Processing Record 3 of Set 3 | kodiak
# Processing Record 4 of Set 3 | invercargill
# Processing Record 5 of Set 3 | vila velha
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | fale old settlement
# Processing Record 8 of Set 3 | boryeong
# Processing Record 9 of Set 3 | keflavik
# Processing Record 10 of Set 3 | hamilton
# Processing Record 11 of Set 3 | kuybyshev
# Processing Record 12 of Set 3 | sao joao da barra
# Processing Record 13 of Set 3 | luanda
# Processing Record 14 of Set 3 | skagen
# Processing Record 15 of Set 3 | vadso
# Processing Record 16 of Set 3 | flying fish cove
# Processing Record 17 of Set 3 | chadan
# Processing Record 18 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 19 of Set 3 | richards bay
# Processing Record 20 of Set 3 | whitehorse
# Processing Record 21 of Set 3 | blackmans bay
# Processing Record 22 of Set 3 | kailua-kona
# Processing Record 23 of Set 3 | nemuro
# Processing Record 24 of Set 3 | medvezh'yegorsk
# Processing Record 25 of Set 3 | caraballeda
# Processing Record 26 of Set 3 | udachny
# Processing Record 27 of Set 3 | tolanaro
# Processing Record 28 of Set 3 | uttar char fasson
# Processing Record 29 of Set 3 | luderitz
# Processing Record 30 of Set 3 | port elizabeth
# Processing Record 31 of Set 3 | rincon de la victoria
# Processing Record 32 of Set 3 | papatowai
# Processing Record 33 of Set 3 | vilyuchinsk
# Processing Record 34 of Set 3 | morazan
# Processing Record 35 of Set 3 | salinopolis
# Processing Record 36 of Set 3 | hastings
# Processing Record 37 of Set 3 | ahau
# City not found. Skipping...
# Processing Record 38 of Set 3 | hobyo
# Processing Record 39 of Set 3 | tanumah
# Processing Record 40 of Set 3 | kimberley
# Processing Record 41 of Set 3 | talnakh
# Processing Record 42 of Set 3 | meleuz
# Processing Record 43 of Set 3 | tangalle
# Processing Record 44 of Set 3 | mugia
# Processing Record 45 of Set 3 | saipan
# Processing Record 46 of Set 3 | island harbour
# Processing Record 47 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 48 of Set 3 | port lincoln
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 0 of Set 4 | naze
# Processing Record 1 of Set 4 | verkhnevilyuysk
# Processing Record 2 of Set 4 | preobrazheniye
# Processing Record 3 of Set 4 | vanimo
# Processing Record 4 of Set 4 | kingston
# Processing Record 5 of Set 4 | salahonda
# Processing Record 6 of Set 4 | chonchi
# Processing Record 7 of Set 4 | penon blanco
# Processing Record 8 of Set 4 | hammerfest
# Processing Record 9 of Set 4 | taoudenni
# Processing Record 10 of Set 4 | kavaratti
# Processing Record 11 of Set 4 | kununurra
# Processing Record 12 of Set 4 | hami
# Processing Record 13 of Set 4 | holualoa
# Processing Record 14 of Set 4 | villiers
# Processing Record 15 of Set 4 | kawthoung
# City not found. Skipping...
# Processing Record 16 of Set 4 | saratamata
# City not found. Skipping...
# Processing Record 17 of Set 4 | solnechniy
# City not found. Skipping...
# Processing Record 18 of Set 4 | egilsstadir
# Processing Record 19 of Set 4 | nagqu
# Processing Record 20 of Set 4 | st. john's
# Processing Record 21 of Set 4 | pontalina
# Processing Record 22 of Set 4 | falmouth
# Processing Record 23 of Set 4 | gadzhiyevo
# Processing Record 24 of Set 4 | ancud
# Processing Record 25 of Set 4 | punta arenas
# Processing Record 26 of Set 4 | phon
# Processing Record 27 of Set 4 | turpan
# Processing Record 28 of Set 4 | san patricio
# Processing Record 29 of Set 4 | jeddah
# Processing Record 30 of Set 4 | hawaiian paradise park
# Processing Record 31 of Set 4 | laguna
# Processing Record 32 of Set 4 | el haouaria
# Processing Record 33 of Set 4 | jinghong
# Processing Record 34 of Set 4 | kuusamo
# Processing Record 35 of Set 4 | ust-nera
# Processing Record 36 of Set 4 | gaigeturi
# Processing Record 37 of Set 4 | vuokatti
# Processing Record 38 of Set 4 | humahuaca
# Processing Record 39 of Set 4 | pante makasar
# City not found. Skipping...
# Processing Record 40 of Set 4 | saint-philippe
# Processing Record 41 of Set 4 | susuman
# Processing Record 42 of Set 4 | klyuchi
# Processing Record 43 of Set 4 | pass christian
# Processing Record 44 of Set 4 | grand falls-windsor
# Processing Record 45 of Set 4 | kidal
# Processing Record 46 of Set 4 | owando
# Processing Record 47 of Set 4 | mejit
# Processing Record 48 of Set 4 | kodinsk
# Processing Record 49 of Set 4 | segorbe
# Processing Record 0 of Set 5 | nar'yan-mar
# Processing Record 1 of Set 5 | phongsali
# Processing Record 2 of Set 5 | kangding
# Processing Record 3 of Set 5 | bubaque
# Processing Record 4 of Set 5 | gornopravdinsk
# Processing Record 5 of Set 5 | akureyri
# Processing Record 6 of Set 5 | three points
# Processing Record 7 of Set 5 | port blair
# Processing Record 8 of Set 5 | aguas formosas
# Processing Record 9 of Set 5 | manatutu
# City not found. Skipping...
# Processing Record 10 of Set 5 | vorgashor
# Processing Record 11 of Set 5 | okhotsk
# Processing Record 12 of Set 5 | fuglafjordur
# Processing Record 13 of Set 5 | bonny
# Processing Record 14 of Set 5 | chilmari
# Processing Record 15 of Set 5 | menongue
# Processing Record 16 of Set 5 | vorkuta
# Processing Record 17 of Set 5 | west helena
# Processing Record 18 of Set 5 | villa yapacani
# Processing Record 19 of Set 5 | argo
# Processing Record 20 of Set 5 | kourou
# Processing Record 21 of Set 5 | west island
# Processing Record 22 of Set 5 | horta
# Processing Record 23 of Set 5 | avarua
# Processing Record 24 of Set 5 | nizhnesortymskiy
# Processing Record 25 of Set 5 | hailar
# Processing Record 26 of Set 5 | dudinka
# Processing Record 27 of Set 5 | altamira
# Processing Record 28 of Set 5 | tsiombe
# Processing Record 29 of Set 5 | moab
# Processing Record 30 of Set 5 | inongo
# Processing Record 31 of Set 5 | callao
# Processing Record 32 of Set 5 | baiyin
# Processing Record 33 of Set 5 | srivardhan
# Processing Record 34 of Set 5 | aykhal
# Processing Record 35 of Set 5 | wuwei
# Processing Record 36 of Set 5 | longyearbyen
# Processing Record 37 of Set 5 | totness
# Processing Record 38 of Set 5 | mitu
# Processing Record 39 of Set 5 | sechura
# Processing Record 40 of Set 5 | kavieng
# Processing Record 41 of Set 5 | howrah
# Processing Record 42 of Set 5 | twon-brass
# Processing Record 43 of Set 5 | hegang
# Processing Record 44 of Set 5 | arno
# Processing Record 45 of Set 5 | kon tum
# Processing Record 46 of Set 5 | college
# Processing Record 47 of Set 5 | new plymouth
# Processing Record 48 of Set 5 | al bawiti
# Processing Record 49 of Set 5 | katsuura
# Processing Record 0 of Set 6 | aasiaat
# Processing Record 1 of Set 6 | kyzyl-mazhalyk
# Processing Record 2 of Set 6 | tomatlan
# Processing Record 3 of Set 6 | sovetskaya gavan'
# Processing Record 4 of Set 6 | monchegorsk
# Processing Record 5 of Set 6 | mamuju
# Processing Record 6 of Set 6 | baoying
# Processing Record 7 of Set 6 | cestos city
# Processing Record 8 of Set 6 | slutsk
# Processing Record 9 of Set 6 | paracuru
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | xicotencatl
# Processing Record 12 of Set 6 | wynyard
# Processing Record 13 of Set 6 | ouesso
# Processing Record 14 of Set 6 | pyay
# Processing Record 15 of Set 6 | san jose village
# City not found. Skipping...
# Processing Record 16 of Set 6 | manaquiri
# Processing Record 17 of Set 6 | acajutla
# Processing Record 18 of Set 6 | ringkobing
# Processing Record 19 of Set 6 | el nido
# Processing Record 20 of Set 6 | douglas
# Processing Record 21 of Set 6 | maloye ganyushkino
# Processing Record 22 of Set 6 | juba
# Processing Record 23 of Set 6 | chernyshevskiy
# Processing Record 24 of Set 6 | erenhot
# Processing Record 25 of Set 6 | namibe
# Processing Record 26 of Set 6 | minas de marcona
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | haenam
# Processing Record 29 of Set 6 | teknaf
# Processing Record 30 of Set 6 | itoman
# Processing Record 31 of Set 6 | nampula
# Processing Record 32 of Set 6 | kathleen
# Processing Record 33 of Set 6 | slyudyanka
# Processing Record 34 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 6 | acapulco de juarez
# Processing Record 36 of Set 6 | puerto lempira
# Processing Record 37 of Set 6 | saiha
# Processing Record 38 of Set 6 | cudillero
# Processing Record 39 of Set 6 | anadyr
# Processing Record 40 of Set 6 | polyarnyy
# Processing Record 41 of Set 6 | veracruz
# Processing Record 42 of Set 6 | paita
# Processing Record 43 of Set 6 | rondonopolis
# Processing Record 44 of Set 6 | tindouf
# Processing Record 45 of Set 6 | zeya
# Processing Record 46 of Set 6 | la passe
# Processing Record 47 of Set 6 | periyanegamam
# Processing Record 48 of Set 6 | kachug
# Processing Record 49 of Set 6 | lodja
# Processing Record 0 of Set 7 | san luis
# Processing Record 1 of Set 7 | kandyagash
# Processing Record 2 of Set 7 | giyani
# Processing Record 3 of Set 7 | maluso
# Processing Record 4 of Set 7 | mount isa
# Processing Record 5 of Set 7 | bolotnoye
# Processing Record 6 of Set 7 | constantia
# Processing Record 7 of Set 7 | codrington
# Processing Record 8 of Set 7 | bardai
# Processing Record 9 of Set 7 | lamar
# Processing Record 10 of Set 7 | raja
# Processing Record 11 of Set 7 | daru
# Processing Record 12 of Set 7 | alaghsas
# Processing Record 13 of Set 7 | orsa
# Processing Record 14 of Set 7 | iskateley
# Processing Record 15 of Set 7 | aginskoye
# Processing Record 16 of Set 7 | turaif
# Processing Record 17 of Set 7 | linxia chengguanzhen
# Processing Record 18 of Set 7 | eyl
# Processing Record 19 of Set 7 | olyokminsk
# Processing Record 20 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 21 of Set 7 | la'ie
# Processing Record 22 of Set 7 | soe
# Processing Record 23 of Set 7 | noumea
# Processing Record 24 of Set 7 | sarikamis
# Processing Record 25 of Set 7 | fort bragg
# Processing Record 26 of Set 7 | haiku-pauwela
# Processing Record 27 of Set 7 | mahebourg
# Processing Record 28 of Set 7 | cat ba
# City not found. Skipping...
# Processing Record 29 of Set 7 | pisco
# Processing Record 30 of Set 7 | fort st. john
# Processing Record 31 of Set 7 | wajir
# Processing Record 32 of Set 7 | taulaga
# Processing Record 33 of Set 7 | chavusy
# Processing Record 34 of Set 7 | el granada
# Processing Record 35 of Set 7 | havran
# Processing Record 36 of Set 7 | toliara
# Processing Record 37 of Set 7 | turtas
# Processing Record 38 of Set 7 | agadez
# Processing Record 39 of Set 7 | nevesinje
# Processing Record 40 of Set 7 | raduzhny
# Processing Record 41 of Set 7 | muzayri'
# City not found. Skipping...
# Processing Record 42 of Set 7 | hasaki
# Processing Record 43 of Set 7 | languyan
# Processing Record 44 of Set 7 | saudarkrokur
# Processing Record 45 of Set 7 | parabel'
# Processing Record 46 of Set 7 | dom pedro
# Processing Record 47 of Set 7 | brisas de zicatela
# Processing Record 48 of Set 7 | segre
# Processing Record 49 of Set 7 | ladybrand
# Processing Record 0 of Set 8 | riachao do jacuipe
# Processing Record 1 of Set 8 | hayma'
# City not found. Skipping...
# Processing Record 2 of Set 8 | takamaka
# City not found. Skipping...
# Processing Record 3 of Set 8 | madang
# Processing Record 4 of Set 8 | lower hutt
# Processing Record 5 of Set 8 | busselton
# Processing Record 6 of Set 8 | mahabe
# City not found. Skipping...
# Processing Record 7 of Set 8 | extrema
# Processing Record 8 of Set 8 | yatagan
# Processing Record 9 of Set 8 | villa de cos
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | igarka
# Processing Record 12 of Set 8 | port mathurin
# Processing Record 13 of Set 8 | timbuktu
# Processing Record 14 of Set 8 | ridgecrest
# Processing Record 15 of Set 8 | saint-paul
# Processing Record 16 of Set 8 | crane
# Processing Record 17 of Set 8 | aras-asan
# Processing Record 18 of Set 8 | fort mcmurray
# Processing Record 19 of Set 8 | ewo
# Processing Record 20 of Set 8 | geraldton
# Processing Record 21 of Set 8 | xacmaz
# Processing Record 22 of Set 8 | nouadhibou
# Processing Record 23 of Set 8 | shakhtinsk
# Processing Record 24 of Set 8 | manggar
# Processing Record 25 of Set 8 | 'ayn al 'arab
# Processing Record 26 of Set 8 | tayshet
# Processing Record 27 of Set 8 | fereydun kenar
# Processing Record 28 of Set 8 | nizhneudinsk
# Processing Record 29 of Set 8 | embi
# Processing Record 30 of Set 8 | sitka
# Processing Record 31 of Set 8 | papao
# Processing Record 32 of Set 8 | malonne
# Processing Record 33 of Set 8 | coruripe
# Processing Record 34 of Set 8 | bodaybo
# Processing Record 35 of Set 8 | viamao
# Processing Record 36 of Set 8 | ola
# Processing Record 37 of Set 8 | magadan
# Processing Record 38 of Set 8 | bistrita
# Processing Record 39 of Set 8 | brody
# Processing Record 40 of Set 8 | galveston
# Processing Record 41 of Set 8 | kimbe
# Processing Record 42 of Set 8 | havelock
# Processing Record 43 of Set 8 | labrador city
# Processing Record 44 of Set 8 | san jose de las matas
# Processing Record 45 of Set 8 | simpang
# Processing Record 46 of Set 8 | enewetak
# Processing Record 47 of Set 8 | i-n-salah
# Processing Record 48 of Set 8 | gaiman
# Processing Record 49 of Set 8 | tubmanburg
# Processing Record 0 of Set 9 | hadibu
# Processing Record 1 of Set 9 | boa vista
# Processing Record 2 of Set 9 | mili
# Processing Record 3 of Set 9 | katima mulilo
# Processing Record 4 of Set 9 | yangor
# City not found. Skipping...
# Processing Record 5 of Set 9 | bannu
# Processing Record 6 of Set 9 | timberlake
# Processing Record 7 of Set 9 | san antonio de pale
# Processing Record 8 of Set 9 | ust'-ilimsk
# Processing Record 9 of Set 9 | george town
# Processing Record 10 of Set 9 | tari
# Processing Record 11 of Set 9 | kapuskasing
# Processing Record 12 of Set 9 | islamorada
# Processing Record 13 of Set 9 | tripoli
# Processing Record 14 of Set 9 | wenling
# Processing Record 15 of Set 9 | nova sintra
# Processing Record 16 of Set 9 | coyhaique
# Processing Record 17 of Set 9 | magistral'nyy
# Processing Record 18 of Set 9 | kone
# Processing Record 19 of Set 9 | danville
# Processing Record 20 of Set 9 | ayacucho
# Processing Record 21 of Set 9 | kapa'a
# Processing Record 22 of Set 9 | tazovsky
# Processing Record 23 of Set 9 | ormara
# Processing Record 24 of Set 9 | lepsy
# Processing Record 25 of Set 9 | altayskoye
# Processing Record 26 of Set 9 | nyurba
# Processing Record 27 of Set 9 | lazaro cardenas
# Processing Record 28 of Set 9 | rongelap
# Processing Record 29 of Set 9 | saint-pierre
# Processing Record 30 of Set 9 | revda
# Processing Record 31 of Set 9 | hassi messaoud
# Processing Record 32 of Set 9 | frolovo
# Processing Record 33 of Set 9 | mutoko
# Processing Record 34 of Set 9 | krasnyy chikoy
# Processing Record 35 of Set 9 | sakete
# Processing Record 36 of Set 9 | pariaman
# Processing Record 37 of Set 9 | dali
# Processing Record 38 of Set 9 | princeville
# Processing Record 39 of Set 9 | coahuayana de hidalgo
# Processing Record 40 of Set 9 | urambo
# Processing Record 41 of Set 9 | pochinok
# Processing Record 42 of Set 9 | trincomalee
# Processing Record 43 of Set 9 | amursk
# Processing Record 44 of Set 9 | yarmouth
# Processing Record 45 of Set 9 | asilah
# Processing Record 46 of Set 9 | gorgan
# Processing Record 47 of Set 9 | tofol
# Processing Record 48 of Set 9 | mantua
# Processing Record 49 of Set 9 | shengli
# Processing Record 0 of Set 10 | waingapu
# Processing Record 1 of Set 10 | asau
# Processing Record 2 of Set 10 | grand baie
# Processing Record 3 of Set 10 | coquimbo
# Processing Record 4 of Set 10 | as sulayyil
# Processing Record 5 of Set 10 | olonkinbyen
# Processing Record 6 of Set 10 | consolacion del sur
# Processing Record 7 of Set 10 | n'dalatando
# Processing Record 8 of Set 10 | rizokarpaso
# Processing Record 9 of Set 10 | rawson
# Processing Record 10 of Set 10 | san borja
# Processing Record 11 of Set 10 | guiuan
# Processing Record 12 of Set 10 | arraial do cabo
# Processing Record 13 of Set 10 | sinabang
# Processing Record 14 of Set 10 | sao jose da coroa grande
# Processing Record 15 of Set 10 | gilgit
# Processing Record 16 of Set 10 | fisterra
# Processing Record 17 of Set 10 | santyoku
# Processing Record 18 of Set 10 | non sang
# Processing Record 19 of Set 10 | port macquarie
# Processing Record 20 of Set 10 | champerico
# Processing Record 21 of Set 10 | tobias barreto
# Processing Record 22 of Set 10 | tura
# Processing Record 23 of Set 10 | boden
# Processing Record 24 of Set 10 | kenai
# Processing Record 25 of Set 10 | itamaraca
# Processing Record 26 of Set 10 | acarau
# Processing Record 27 of Set 10 | manicore
# Processing Record 28 of Set 10 | palikir - national government center
# Processing Record 29 of Set 10 | sona
# Processing Record 30 of Set 10 | tucuma
# Processing Record 31 of Set 10 | berezovyy
# Processing Record 32 of Set 10 | dakhla
# Processing Record 33 of Set 10 | sinop
# Processing Record 34 of Set 10 | salinas
# Processing Record 35 of Set 10 | formosa
# Processing Record 36 of Set 10 | north bend
# Processing Record 37 of Set 10 | sahavato
# City not found. Skipping...
# Processing Record 38 of Set 10 | morada nova
# Processing Record 39 of Set 10 | doaba
# Processing Record 40 of Set 10 | pechora
# Processing Record 41 of Set 10 | kalajoki
# Processing Record 42 of Set 10 | mirabela
# Processing Record 43 of Set 10 | lavelanet
# Processing Record 44 of Set 10 | jakobstad
# Processing Record 45 of Set 10 | kirensk
# Processing Record 46 of Set 10 | myeik
# Processing Record 47 of Set 10 | berezovo
# Processing Record 48 of Set 10 | mahajanga
# Processing Record 49 of Set 10 | kingscliff
# Processing Record 0 of Set 11 | parnamirim
# Processing Record 1 of Set 11 | ad dabbah
# Processing Record 2 of Set 11 | ouellah
# City not found. Skipping...
# Processing Record 3 of Set 11 | broken hill
# Processing Record 4 of Set 11 | mancio lima
# Processing Record 5 of Set 11 | ballina
# Processing Record 6 of Set 11 | wenchang
# Processing Record 7 of Set 11 | birjand
# Processing Record 8 of Set 11 | san pedro
# Processing Record 9 of Set 11 | ad-damazin
# Processing Record 10 of Set 11 | dryden
# Processing Record 11 of Set 11 | belyy yar
# Processing Record 12 of Set 11 | rabo de peixe
# Processing Record 13 of Set 11 | macapa
# Processing Record 14 of Set 11 | margate
# Processing Record 15 of Set 11 | antofagasta
# Processing Record 16 of Set 11 | barra da estiva
# Processing Record 17 of Set 11 | malchin
# Processing Record 18 of Set 11 | remire-montjoly
# Processing Record 19 of Set 11 | mikun'
# Processing Record 20 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 21 of Set 11 | balkanabat
# Processing Record 22 of Set 11 | tumaco
# Processing Record 23 of Set 11 | yeppoon
# Processing Record 24 of Set 11 | san martin
# Processing Record 25 of Set 11 | arkhangel'sk
# Processing Record 26 of Set 11 | matoury
# Processing Record 27 of Set 11 | chibougamau
# Processing Record 28 of Set 11 | tralee
# Processing Record 29 of Set 11 | millville
# Processing Record 30 of Set 11 | haldibari
# Processing Record 31 of Set 11 | tozkhurmato
# Processing Record 32 of Set 11 | bay roberts
# Processing Record 33 of Set 11 | kedrovyy
# Processing Record 34 of Set 11 | al burayqah
# Processing Record 35 of Set 11 | balabac
# Processing Record 36 of Set 11 | kawm umbu
# Processing Record 37 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 38 of Set 11 | princeton
# Processing Record 39 of Set 11 | peniche
# Processing Record 40 of Set 11 | eagle
# Processing Record 41 of Set 11 | strezhevoy
# Processing Record 42 of Set 11 | bandarbeyla
# Processing Record 43 of Set 11 | obidos
# Processing Record 44 of Set 11 | kalianget
# Processing Record 45 of Set 11 | egersund
# Processing Record 46 of Set 11 | novyy urgal
# Processing Record 47 of Set 11 | coleraine
# Processing Record 48 of Set 11 | bandrele
# Processing Record 49 of Set 11 | calama
# Processing Record 0 of Set 12 | nuuk
# Processing Record 1 of Set 12 | moree
# Processing Record 2 of Set 12 | espargos
# City not found. Skipping...
# Processing Record 3 of Set 12 | lahij
# Processing Record 4 of Set 12 | farafangana
# Processing Record 5 of Set 12 | qapqal
# City not found. Skipping...
# Processing Record 6 of Set 12 | rundu
# Processing Record 7 of Set 12 | durgapur
# Processing Record 8 of Set 12 | walvis bay
# Processing Record 9 of Set 12 | zinjibar
# Processing Record 10 of Set 12 | sao tome
# Processing Record 11 of Set 12 | port lavaca
# Processing Record 12 of Set 12 | milford haven
# Processing Record 13 of Set 12 | suva
# Processing Record 14 of Set 12 | vallenar
# Processing Record 15 of Set 12 | cable beach
# City not found. Skipping...
# Processing Record 16 of Set 12 | neelankarai
# Processing Record 17 of Set 12 | darhan
# Processing Record 18 of Set 12 | kalmunai
# Processing Record 19 of Set 12 | saint-louis
# Processing Record 20 of Set 12 | batang berjuntai
# Processing Record 21 of Set 12 | xining
# Processing Record 22 of Set 12 | dhidhdhoo
# Processing Record 23 of Set 12 | masaya sur
# Processing Record 24 of Set 12 | sao sebastiao do paraiso
# Processing Record 25 of Set 12 | andkhoy
# Processing Record 26 of Set 12 | mao
# Processing Record 27 of Set 12 | kirklareli
# Processing Record 28 of Set 12 | vodnyy
# Processing Record 29 of Set 12 | malango
# Processing Record 30 of Set 12 | mersa matruh
# Processing Record 31 of Set 12 | kenora
# Processing Record 32 of Set 12 | naberera
# Processing Record 33 of Set 12 | laghouat
# Processing Record 34 of Set 12 | saint-joseph
# Processing Record 35 of Set 12 | ressano garcia
# Processing Record 36 of Set 12 | sur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': 59.5289, 'lat': 22.5667},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 30.96,
#   'feels_like': 34.04,
#   'temp_min': 30.96,
#   'temp_max': 30.96,
#   'pressure': 998,
#   'humidity': 57,
#   'sea_level': 998,
#   'grnd_level': 997},
#  'visibility': 10000,
#  'wind': {'speed': 5.02, 'deg': 205, 'gust': 5.99},
#  'clouds': {'all': 100},
#  'dt': 1693004464,
#  'sys': {'country': 'OM', 'sunrise': 1693014156, 'sunset': 1693059933},
#  'timezone': 14400,
#  'id': 286245,
#  'name': 'Sur',
#  'cod': 200}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          559
# Lat           559
# Lng           559
# Max Temp      559
# Humidity      559
# Cloudiness    559
# Wind Speed    559
# Country       559
# Date          559
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                ebon   4.5820  168.6964     28.61        76         100
# 1            phulbani  20.4667   84.2333     21.89        93          91
# 2  humberto de campos  -2.5983  -43.4611     25.07        87           9
# 3         port alfred -33.5906   26.8910     11.21        88          59
# 4       mount gambier -37.8333  140.7667      9.20        71          89
#
#    Wind Speed Country        Date
# 0        6.49      MH  1693004334
# 1        1.82      IN  1693004334
# 2        2.94      BR  1693004334
# 3        2.68      ZA  1693004335
# 4        2.95      AU  1693004335

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      ebon   4.5820  168.6964     28.61        76
# 1                  phulbani  20.4667   84.2333     21.89        93
# 2        humberto de campos  -2.5983  -43.4611     25.07        87
# 3               port alfred -33.5906   26.8910     11.21        88
# 4             mount gambier -37.8333  140.7667      9.20        71
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        6.49      MH  1693004334
# 1                91        1.82      IN  1693004334
# 2                 9        2.94      BR  1693004334
# 3                59        2.68      ZA  1693004335
# 4                89        2.95      AU  1693004335

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter", grid=True,x='Lat',y='Max Temp',
                  title=f"City Latitude vs Max Temperature",
                  figsize=(8,6))

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter", grid=True, x='Lat', y='Humidity',
                  title=f"City Latitue vs Humidity",
                  figsize=(8,6))

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity %')

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind="scatter", grid = True, x = 'Lat', y = 'Cloudiness',
                  title=f"City Ltitude vs Cloudiness",
                  figsize=(8,6))

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind="scatter", grid=True,x='Lat',y='Wind Speed',
                  title=f"City Latitude vs Wind Speed ({pd.to_datetime('today').date()})",
                  figsize=(8,5))

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linearplot(x_values,y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values*slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values, y_values)
    a=int(input('Where do you want to put the equation on this graph? x-coordinate ='))
    b=int(input('y-coordinate ='))
    plt.annotate(line_eq, (a,b), frontsize=15, color="red")
    plt.plot(x_values, regress_values, "r-")
    plt.xlabel('Latitude')
    print(f"The r-squared is: {rvalue**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[city_data_df['Lat']>0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                ebon   4.5820  168.6964     28.61        76         100
# 1            phulbani  20.4667   84.2333     21.89        93          91
# 10          ilulissat  69.2167  -51.1000      4.72        84          91
# 12       tanjungtiram   4.0613   98.3699     23.78        93          99
# 14           smithers  54.7804 -127.1743     26.18        29           0
#
#          Wind Speed Country        Date
# City_ID
# 0              6.49      MH  1693004334
# 1              1.82      IN  1693004334
# 10             2.95      GL  1693004336
# 12             1.48      ID  1693004337
# 14             3.09      CA  1693004337

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2        humberto de campos  -2.5983  -43.4611     25.07        87
# 3               port alfred -33.5906   26.8910     11.21        88
# 4             mount gambier -37.8333  140.7667      9.20        71
# 5                 adamstown -25.0660 -130.1015     18.89        60
# 6         port-aux-francais -49.3500   70.2167      2.93        78
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                 9        2.94      BR  1693004334
# 3                59        2.68      ZA  1693004335
# 4                89        2.95      AU  1693004335
# 5                26        5.98      PN  1693004335
# 6               100       13.72      TF  1693004335

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
